# %%
import json
import numpy as np
import networkx as nx
from collections import defaultdict, Counter
from typing import Dict, List, Tuple
import os
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings('ignore')

# For embeddings and similarity computation
try:
    from sentence_transformers import SentenceTransformer
    from sklearn.metrics.pairwise import cosine_similarity
    print("Required libraries imported successfully!")
except ImportError as e:
    print(f"Missing library: {e}")
    print("Please install with: pip install sentence-transformers scikit-learn networkx")

np.random.seed(42)
# Out:
# Required libraries imported successfully!

# %%
from scipy.sparse import find, csr_matrix
import matplotlib.pyplot as plt
import pandas as pd
from scipy.linalg import norm
from IPython.core.display import HTML

# des options permettent de limiter (ou non) le nombre de lignes/colonnes affichées
# par exemple :
# pd.set_option('display.max_rows', None)

# cette fonction permet d'afficher une "jolie" représentation du vecteur v
# ARGS :
#   v : le vecteur à afficher (par ex. une ligne de la matrice X)
#   features : le vocabulaire
#   top_n : le nombre de mots maximum à afficher
def print_feats(v, features, top_n = 30):
    _, ids, values = find(v)
    feats = [(ids[i], values[i], features[ids[i]]) for i in range(len(list(ids)))]
    top_feats = sorted(feats, key=lambda x: x[1], reverse=True)[0:top_n]
    return pd.DataFrame({"word" : [t[2] for t in top_feats], "value": [t[1] for t in top_feats]})   

# fonction qui permet d'afficher plusieurs tables pandas côte à côte (c'est cadeau)
def display_side_by_side(dfs:list, captions:list):
    """Display tables side by side to save vertical space
    Input:
        dfs: list of pandas.DataFrame
        captions: list of table captions
    """
    output = ""
    combined = dict(zip(captions, dfs))
    for caption, df in combined.items():
        output += df.style.set_table_attributes("style='display:inline'").set_caption(caption)._repr_html_()
        output += "&emsp;"
        #output += "\xa0\xa0\xa0"
    display(HTML(output))

# %% [markdown]
# # 1. Chargement et prise en main des données

# %%
def load_corpus(file_path: str) -> Dict[str, Dict]:
    """
    Load corpus data from a JSONL file.
    Returns a dictionary mapping document IDs to their associated metadata.
    """
    corpus = {}
    
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():  # skip empty lines
                doc = json.loads(line)
                doc_id = doc.get("_id")
                if doc_id is not None:
                    corpus[doc_id] = doc
                    
    return corpus


def load_queries(file_path: str) -> Dict[str, Dict]:
    """
    Load query data from a JSONL file.
    Returns a dictionary mapping query IDs to query metadata.
    """
    queries = {}
    
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                q = json.loads(line)
                q_id = q.get("_id")
                if q_id is not None:
                    queries[q_id] = q
                    
    return queries


def load_qrels(file_path: str) -> Dict[str, Dict[str, int]]:
    """
    Load relevance judgments from a TSV file.
    Returns a dictionary:
        { query_id : { candidate_id : relevance_score } }
    """
    qrels = {}
    
    with open(file_path, "r", encoding="utf-8") as f:
        next(f) #On saute l'en-tête
        for line in f:
            parts = line.strip().split("\t")
            if len(parts) != 3:
                continue  
            
            q_id, c_id, score = parts
            score = int(score)

            if q_id not in qrels:
                qrels[q_id] = {}
            qrels[q_id][c_id] = score
    
    return qrels

# Load the dataset
print("Loading dataset...")
corpus = load_corpus('dataset_BE2/corpus.jsonl')
queries = load_queries('dataset_BE2/queries.jsonl')
qrels_valid = load_qrels('dataset_BE2/valid.tsv')


print(f"Loaded {len(corpus)} documents in corpus")
print(f"Loaded {len(queries)} queries")
print(f"Loaded relevance for {len(qrels_valid)} queries (dataset)")
# Out:
# Loading dataset...
# Loaded 25657 documents in corpus
# Loaded 1000 queries
# Loaded relevance for 700 queries (dataset)

# %% [markdown]
# # 2 - Exploration des données et premier encodage

# %%
nb_docs = len(corpus)
nb_queries = len(queries)
nb_pairs = sum(len(docs) for docs in qrels_valid.values()) #on prend chaque dictionnaire de documents pour chaque requête et on somme
proportions = []
for qid, docs in qrels_valid.items(): ##[..].items contient une ligne par requête avec id de chaque document et score
    total_docs = len(docs)
    if total_docs == 0:
        continue  
    num_positifs = sum(1 for score in docs.values() if score == 1)
    proportion = num_positifs / total_docs
    proportions.append(proportion)

moyenne_proportion = sum(proportions) / len(proportions)

print(f"Taille du corpus : {nb_docs} documents")
print(f"Nombre de requêtes : {nb_queries}")
print(f"Nombre total de paires requête/document : {nb_pairs}")
print(f"Proportion d'articles pertinents par requète : {round(moyenne_proportion*100)}%")
# Out:
# Taille du corpus : 25657 documents
# Nombre de requêtes : 1000
# Nombre total de paires requête/document : 20950
# Proportion d'articles pertinents par requète : 16%

# %%
def show_example_query(corpus, queries, qrels, q_id=None):

    if q_id is None:
        q_id = next(iter(queries))  # prend la première requete

    query = queries[q_id]

    print("Requête")
    print("ID :", q_id)
    print("Titre :", query.get("text"))
    print()

    # On sépare les positifs des négatifs
    candidates = qrels[q_id]
    positives = [c for c, s in candidates.items() if s == 1]
    negatives = [c for c, s in candidates.items() if s == 0]

    # On affiche des candidats
    print("Candidats positifs")
    for c_id in positives[:3]:
        print("-", corpus[c_id]["title"])
    print()

    print("Candidats négatifs")
    for c_id in negatives[:3]:
        print("-", corpus[c_id]["title"])

show_example_query(corpus, queries, qrels_valid)
# Out:
# Requête
# ID : 78495383450e02c5fe817e408726134b3084905d
# Titre : A Direct Search Method to solve Economic Dispatch Problem with Valve-Point Effect
#
# Candidats positifs
# - A Hybrid EP and SQP for Dynamic Economic Dispatch with Nonsmooth Fuel Cost Function
# - A modified particle swarm optimizer
# - Identification and control of dynamic systems using recurrent fuzzy neural networks
#
# Candidats négatifs
# - A data mining approach for location prediction in mobile environments
# - Treatment-Response Models for Counterfactual Reasoning with Continuous-time, Continuous-valued Interventions
# - Dissecting and Reassembling Color Correction Algorithms for Image Stitching

# %% [markdown]
# ### Premier encodage des données

# %%
def extract_titles(corpus, queries):
    #Retourne une liste des titres du corpus + queries ainsi que les IDs correspondants
    texts=[]
    ids=[]

    #corpus
    for doc_id, doc in corpus.items():
        title = doc.get("title", "").strip()
        texts.append(title)
        ids.append(doc_id)
    
    #requêtes
    for q_id, query in queries.items():
        title=query.get("text")
        texts.append(title.strip())
        ids.append(q_id)

    return texts, ids

from sklearn.feature_extraction.text import CountVectorizer

def build_document_term_matrix(texts):
    #vectorizer= CountVectorizer(max_features=5000, stop_words='english', min_df=2, max_df=0.8)
    vectorizer= TfidfVectorizer(max_features=5000, stop_words='english', min_df=2, max_df=0.8) 
    # Taille maximale du vocabulaire = max_features
    # suppression des mots-outils de la langue anglaise
    # suppression des mots trop rares (apparaissant dans un seul article) ou trop fréquents (apparaissant dans 80% des articles ou plus)
    # stemming ?
    # Pondération par TF-IDF : donne plus d'importance aux mots discriminants et réduit l’influence des mots fréquents
    X = vectorizer.fit_transform(texts)
    return X, vectorizer

texts, ids = extract_titles(corpus, queries)
X, vectorizer = build_document_term_matrix(texts)

print(X.shape)
print("Longueur du vocabulaire :", len(vectorizer.get_feature_names_out()))

# Exemple : affichage des 3 termes les plus fréquents du 3è document (dans son titre)
features = vectorizer.get_feature_names_out()
example_vec=X[2]
display(print_feats(example_vec,features, top_n=3))
# Out:
# (26657, 5000)
# Longueur du vocabulaire : 5000
#      word     value
# 0   fuzzy  0.598473
# 1   bases  0.381727
# 2  tuning  0.364401

# %% [markdown]
# ### Distribution des mots les plus fréquemment employés dans le corpus

# %%
from scipy.sparse import csr_matrix

term_frequencies = np.asarray(X.sum(axis=0)).ravel()
freq_vector = csr_matrix(term_frequencies)
features = vectorizer.get_feature_names_out()

#Affichage des 30 mots les plus fréquents
top_words=print_feats(freq_vector,features, top_n=30)
display(top_words)

#Affichage graphique
plt.figure(figsize=(8,4))
plt.bar(top_words["word"], top_words["value"])
plt.xticks(rotation=90)
plt.xlabel("Mots")
plt.ylabel("Nombre d'ccurrences")
plt.title("Fréquence des mots dans l'ensemble du corpus")
plt.show()
# Out:
#               word       value
# 0            based  511.738909
# 1            using  485.756967
# 2         learning  470.430844
# 3             data  353.416084
# 4         networks  343.130528
# 5         analysis  316.094841
# 6        detection  311.993531
# 7           neural  287.721266
# 8             deep  252.926585
# 9      recognition  236.916577
# 10         network  232.580501
# 11           model  224.432191
# 12         systems  223.734504
# 13        approach  212.743030
# 14          design  210.161202
# 15           image  206.661473
# 16  classification  197.950264
# 17           multi  179.522431
# 18          social  176.984288
# 19          review  174.700062
# 20         control  173.932005
# 21            time  173.860442
# 22    applications  166.845974
# 23         machine  165.177121
# 24          survey  163.960533
# 25       algorithm  162.562348
# 26          models  161.157721
# 27     information  160.993311
# 28           study  157.847793
# 29            high  149.649658

# %% [markdown]
# # 3. Comparaison de documents et premier moteur de recherche

# %% [markdown]
# ### Comparaison de documents

# %% [markdown]
# D'abord, sans prise en compte des résumés, seulement des titres.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def compare_docs(i,j,X,ids,corpus):
    v1=X[i]
    v2=X[j]
    sim = cosine_similarity(v1,v2)[0,0]

    print(f"Cosine similarity entre {ids[i]} et {ids[j]} : {sim:.4f}\n")
    print("Doc1 : ", corpus.get(ids[i], {}).get("title", ""))
    print("Doc2 : ", corpus.get(ids[j], {}).get("title", ""))

    #Affichage des mots en commun :
    common = v1.multiply(v2)
    display(print_feats(common,features, top_n=20))

compare_docs(10, 7, X, ids, corpus)
# Out:
# Cosine similarity entre 9f234867df1f335a76ea07933e4ae1bd34eeb48a et 1ae0ac5e13134df7a0d670fc08c2b404f1e3803c : 0.1044
#
# Doc1 :  Automatic Machine Translation Evaluation: A Qualitative Approach
# Doc2 :  A data mining approach for location prediction in mobile environments
#        word     value
# 0  approach  0.104424

# %% [markdown]
# En ne prenant en compte que les titres, il est logiquement difficile de trouver des similarités entre 2 documents différents.

# %%
def extract_title_and_text(corpus):
    texts=[]
    ids=[]
    for doc_id, doc in corpus.items():
        txt=(doc.get("title","") + " " + doc.get("text","")).strip()
        texts.append(txt)
        ids.append(doc_id)
    return texts, ids

texts_full, ids_full = extract_title_and_text(corpus)
X_full, vectorizer_full = build_document_term_matrix(texts_full)

# %% [markdown]
# Premier moteur de recherche, qui prend un ensemble de mots clefs, calcule un score pour chaque document de la base et retourne les 10 premieres résultats.

# %%
def search_engine(query_text, vectorizer, X, ids, corpus, top_k=10):
    # On encode la requête avec le même vectorizer
    q_vec=vectorizer.transform([query_text])

    similarities = cosine_similarity(q_vec, X)[0]
    #On récupère les indices des documents triés par score décroissant
    top_idx = similarities.argsort()[::-1][:top_k]

    results= []
    print("Meilleurs résumtats pour la requête \"", query_text,"\" :\n")
    for idx in top_idx:
        doc_id = ids[idx]
        title = corpus[doc_id].get("title", "")
        score = similarities[idx]
        results.append((doc_id, title, score))

        print(f"[score={score:.4f}] {title}")

    return results

results = search_engine("graph neural networks for chemistry", vectorizer_full, X_full, ids_full, corpus, top_k=10)
# Out:
# Meilleurs résumtats pour la requête " graph neural networks for chemistry " :
#
# [score=0.5453] Semi-Supervised Classification with Graph Convolutional Networks
# [score=0.5159] Graph Embedding Problem Settings Graph Embedding Input Graph Embedding Output Homogeneous Graph Heterogeneous Graph Graph with Auxiliary Information Graph Constructed from Non-relational Data Node Embedding Edge Embedding Hybrid Embedding Whole-Graph Embedding Graph Embedding Techniques Matrix Facto
# [score=0.5095] Neural Graph Machines: Learning Neural Networks Using Graphs
# [score=0.4815] Graph construction and b-matching for semi-supervised learning
# [score=0.4780] Graph2Seq: Scalable Learning Dynamics for Graphs
# [score=0.4659] Computational Capabilities of Graph Neural Networks
# [score=0.4656] Query Optimization Techniques In Graph Databases
# [score=0.4540] G-SQL: Fast Query Processing via Graph Exploration
# [score=0.4538] Designing Neural Networks Using Genetic Algorithms with Graph Generation System
# [score=0.4457] Graph Databases

# %% [markdown]
# Essayons quelques variantes, en :
# - Modifiant les paramètres du "vectoriseur" : taille du vocabulaire, suppression des mots-outils, suppression des mots trop rares ou trop fréquents, stemming (réduit les mots à leurs racines)
# - Utilisant une autre pondération, comme TFxIDF (système qui donne du poids à des mots importants, n'en donne pas à des mots de liaisons par exemple)

# %% [markdown]
# Toutes ces options ne permettent pas forcément d'augmenter les scores obtenus par search_engine, mais contribuent à rendre ces scores plus adéquats.

# %% [markdown]
# # 4. Utiliser un meilleur encodeur de documents

# %% [markdown]
# On cherche à utiliser un encodage spécialisé pour construire des représentations denses beaucoup plus adaptées à ces données. Pour cela, on suit 3 étapes :
# - Construction des embeddings (transformer une information en objet numérique)
# - Sauvegarde dans un fichier
# - Chargement des embeddings s'ils existent déjà

# %%
import os
import numpy as np
from sentence_transformers import SentenceTransformer

MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"
EMBEDDINGS_FILE = "embeddings.npy"
TEXT_FILE = "corpus.npy"

def get_embeddings(texts):
    # Charge le fichier s'il existe déjà
    if os.path.exists(EMBEDDINGS_FILE):
        print("Chargement des embeddings")
        embeddings = np.load(EMBEDDINGS_FILE)
        return embeddings
    
    # SInon
    print("Calcul des embeddings")
    model = SentenceTransformer(MODEL_NAME)
    embeddings = model.encode(texts, show_progress_bar=True)
    print("Sauvegarde dans", EMBEDDINGS_FILE)
    np.save(EMBEDDINGS_FILE, embeddings)

    return embeddings

texts = [(doc.get("title","") + " " + doc.get("text","")).strip() for doc in corpus.values()]

embeddings = get_embeddings(texts)
print("taille des embeddings :", embeddings.shape)
# Out:
# Calcul des embeddings
# Batches: 100%|██████████| 802/802 [05:27<00:00,  2.45it/s]
# Sauvegarde dans embeddings.npy
# taille des embeddings : (25657, 384)

# %% [markdown]
# # 5. Nouveau moteur de recherche

# %% [markdown]
# A présent, l'objectif est double :
#
# - Implémenter un moteur de recherche, mais cette fois en vous basant sur les représentations denses construites à l'étape précédente.
# - Evaluer la pertinence de votre moteur grâce aux annotations fournies dans le fichier valid.tsv qui portent sur les requêtes de query.tsv : pour une requête donnée, votre système doit retourner préférentiellement les articles pertinents (score noté 1) en comparaison des articles non pertinents (score noté 0).
#
# Commençons par implémenter le moteur de recherche proprement dit : à partir d'une requête, le système doit trier les 25 documents candidats fournis.

# %%
corpus_ids = list(corpus.keys()) #même ordre que pour l'encodage
id_to_index = {doc_id: i for i, doc_id in enumerate(corpus_ids)}

model = SentenceTransformer("all-MiniLM-L6-v2")

def encode_query(query):
    text = query.get("text", "").strip() 
    return model.encode([text])[0]  # vecteur 1 dimension

def search_with_embeddings(query, candidate_ids, embeddings, id_to_index):
    q_emb = encode_query(query).reshape(1,-1) #encode la requête
    cand_embs = np.array([embeddings[id_to_index[cid]] for cid in candidate_ids])
    sims = cosine_similarity(q_emb, cand_embs)[0] #shape = 25
    # Tri par ordre décroissant de scopre
    ranked_candidates = sorted(zip(candidate_ids, sims), key=lambda x: x[1], reverse=True)

    return ranked_candidates

#Test de la query 1 :
query_id = list(queries.keys())[0]
query = queries[query_id]
candidate_ids = list(qrels_valid[query_id].keys())
ranked=search_with_embeddings(query, candidate_ids,embeddings, id_to_index)

# Affichage des 10 documents les plus pertinents avec leur score
for doc_id, score in ranked[:10]:
    print(f"{score:.4f} - {corpus[doc_id]['title']}")
# Out:
# 0.5769 - A Hybrid EP and SQP for Dynamic Economic Dispatch with Nonsmooth Fuel Cost Function
# 0.2485 - A hybrid of genetic algorithm and particle swarm optimization for recurrent network design
# 0.2355 - A modified particle swarm optimizer
# 0.2335 - Genetic Fuzzy Systems - Evolutionary Tuning and Learning of Fuzzy Knowledge Bases
# 0.1860 - Identification and control of dynamic systems using recurrent fuzzy neural networks
# 0.1675 - Scheduling for Reduced CPU Energy
# 0.1636 - Predictive Control of Power Converters: Designs With Guaranteed Performance
# 0.0713 - Compressed Nonparametric Language Modelling
# 0.0538 - Automatic Machine Translation Evaluation: A Qualitative Approach
# 0.0375 - A data mining approach for location prediction in mobile environments

# %% [markdown]
# Maintenant, on va tester avec quelques requêtes si les documents évalués avec les meilleurs scores de similitude sont bien notés comme pertinents dans qrels_valid (score = 1).

# %%
import random

# Sélection de 3 requêtes aléatoires pour l'exemple
qrel_keys = list(qrels_valid.keys())
#query_ids_to_test = list(queries.keys())[:3]
N_TESTS = 3
query_ids_to_test = random.sample(qrel_keys, N_TESTS)

for q_id in query_ids_to_test:
    query = queries[q_id]
    
    # On récupère tous les documents jugés pour cette requête
    candidate_ids = list(qrels_valid[q_id].keys())
    
    ranked_results = search_with_embeddings(query, candidate_ids, embeddings, id_to_index)
    
    print(f"REQUÊTE : {query['text']}")
    print(f"{'Rang':<4} | {'Similitude':<10} | {'Pertinence (QREL)':<20} | Titre du Document")
    
    # Affiche les 5 premiers résultats
    for rank, (doc_id, score) in enumerate(ranked_results[:5]):
        # Récupère le score QREL (1 si pertinent, 0 ou absence si non pertinent)
        qrel_score = qrels_valid[q_id].get(doc_id, 0)
        
        # Le QREL score 1 est la marque de la pertinence
        is_relevant = " Score 1" if qrel_score == 1 else " Score 0"
        
        doc_title = corpus[doc_id].get('title', 'Titre non disponible')
        
        print(f"{rank + 1:<4} | {score:.4f}     | {is_relevant:<20} | {doc_title}")
# Out:
# REQUÊTE : Mobile cloud sensing, big data, and 5G networks make an intelligent and smart world
# Rang | Similitude | Pertinence (QREL)    | Titre du Document
# 1    | 0.3076     |  Score 1             | Crowdsourcing to smartphones: incentive mechanism design for mobile phone sensing
# 2    | 0.2496     |  Score 0             | Artificial Intelligence and Soft Computing: Behavioral and Cognitive Modeling of the Human Brain
# 3    | 0.1680     |  Score 0             | Automatic License Plate Recognition: a Review
# 4    | 0.1457     |  Score 0             | A Three-Step Vehicle Detection Framework for Range Estimation Using a Single Camera
# 5    | 0.1450     |  Score 0             | The Fifth 'CHiME' Speech Separation and Recognition Challenge: Dataset, Task and Baselines
# REQUÊTE : Entity-Aware Language Model as an Unsupervised Reranker
# Rang | Similitude | Pertinence (QREL)    | Titre du Document
# 1    | 0.4354     |  Score 1             | KenLM: Faster and Smaller Language Model Queries
# 2    | 0.3974     |  Score 0             | Maintaining Views Incrementally
# 3    | 0.3697     |  Score 1             | Context dependent recurrent neural network language model
# 4    | 0.3550     |  Score 0             | Multi-document English Text Summarization using Latent Semantic Analysis
# 5    | 0.3048     |  Score 0             | Off-policy evaluation for slate recommendation
# REQUÊTE : On Parallelizing the Multiprocessor Scheduling Problem
# Rang | Similitude | Pertinence (QREL)    | Titre du Document
# 1    | 0.6264     |  Score 1             | Efficient Scheduling of Arbitrary TAsk Graphs to Multiprocessors Using a Parallel Genetic Algorithm
# 2    | 0.5600     |  Score 1             | Scheduling Precedence Graphs in Systems with Interprocessor Communication Times
# 3    | 0.5052     |  Score 1             | A Taxonomy of Scheduling in General-Purpose Distributed Computing Systems
# 4    | 0.4697     |  Score 1             | Hypertool: A Programming Aid for Message-Passing Systems
# 5    | 0.3761     |  Score 1             | A Microprocessor-based Hypercube Supercomputer

# %% [markdown]
# Avec le choix random de requètes, on n'observe pas toujours un top 5 documents avec un score de 1. Néanmoins, on l'observe bien quand les scores de similitudes de ce top 5 sont relativement élevés (tous > 0.3 environ). Celà est compréhensible: l'évaluation du doc "query" est limitée par le volume du corpus.

# %% [markdown]
# Arrive maintenant l'étape la plus cruciale: évaluer notre moteur. Pour cela, on va faire tourner le moteur de recherche sur l'ensemble des requêtes du fichier et calculer des indicateurs de qualité:
# - *précision* : proportion de documents réellement pertinents parmis tous les documents classés comme pertinents par le moteur (le top-k)
# - *rappel* : proportion de documents pertinents retrouvés (classés dans le top-k) parmi tous les documents pertinents réels (score qrel = 1).
# - *f-mesure* : permet d'assurer que les scores de précision et rappel n'ont pas d'écarts extrêmes (moyenne harmonique de précision et rappel)
# - *AUC* : probabilité qu'un document réellement pertinent ait un meilleur score qu'un document non pertinent. C'est l'aire sous la courbe ROC (Area Under the Curve) qui trace le taux de vrais positifs par rapport au taux de faux positifs.
#
# Pour le calcul de l'AUC, on doit évaluer tous les documents du corpus, là ou le top-k suffit pour calculer les autres indicateurs. On créé donc une deuxième fonction spécifique à ce calcul. Dans cette fonction de calcul de l'AUC, on utilise la fonction python *roc_auc_score* qui permet de calculer l'aire à partir des labels binaires de qrels et des scores de similitude. En effet, les scores permettent de classer les documents les un après les autres, le label binaire de savoir si le document est pertinent, et ainsi d'avoir la probabilité d'avoir un document pertinent mieux classé(selon le score) qu'un document non pertinent.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

## Calcul des métriques
def calculate_metrics_at_k(q_id, ranked_results, qrels, k=10):
    qrel_dict = qrels[q_id]

    top_k_results = ranked_results[:k] #Identifier le top k documents pertinents
    
    # y_true (vérité terrain) et y_pred (prédiction)
    # Nous allons créer des listes alignées (longueur K)
    y_true = [] #score qrel de chaque document
    y_pred = [] # La prédiction est binaire: 1 si le document est classé, 0 sinon.
                # Ici, on simplifie : les k premiers sont "prédits" comme pertinents.

    for doc_id, score in top_k_results:
        # Le score de pertinence (1 ou 0)
        y_true.append(qrel_dict.get(doc_id, 0)) 
        # La prédiction est que ce document est pertinent (car il est dans le Top-K)
        y_pred.append(1) 
        
    # Cas où il y a moins de K résultats jugés 
    if len(y_true) < k:
        pass
    
    precision = precision_score(y_true, y_pred, zero_division=0)
    
    total_relevant = sum(qrel_dict.values())  # Total des pertinents réels (nombre de 1 dans qrels)
    
    relevant_retrieved = sum(y_true) # Nombre de pertinents retrouvés dans le Top-k
    
    # Si le total réel est zéro (aucune vraie pertinence), le Rappel est 0
    recall = relevant_retrieved / total_relevant if total_relevant > 0 else 0
    
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    return precision, recall, f1, total_relevant

def calculate_auc(q_id, ranked_results, qrels):
    qrel_dict = qrels[q_id]
        
    y_true = [] # Labels binaires de qrels
    y_scores = [] # Scores de similarité (prédictions)

    for doc_id, score in ranked_results:
        y_scores.append(score)
        y_true.append(qrel_dict.get(doc_id, 0))
    
    if 1 in y_true and 0 in y_true:
        auc = roc_auc_score(y_true, y_scores) 
        return auc
    else:
        return np.nan # Si l'AUC ne peut pas être calculée car tous les scores sont les mêmes

## Application
all_precision = []
all_recall = []
all_f1 = []
all_auc = []
valid_query_count = 0

K = 10 

qrel_keys = list(qrels_valid.keys())
print(f"Démarrage de l'évaluation sur {len(qrel_keys)} requêtes.")

for q_id in qrel_keys:
    query = queries.get(q_id)
    
    # Vérification que la requête existe dans le dictionnaire 'queries'
    if not query:
        continue

    # Récupérer les candidats jugés 
    candidate_ids = list(qrels_valid[q_id].keys())
    
    # Le moteur de recherche
    try:
        ranked_results = search_with_embeddings(query, candidate_ids, embeddings, id_to_index)
        p, r, f1, total_relevant = calculate_metrics_at_k(q_id, ranked_results, qrels_valid, k=K)
        
        # Nous n'incluons que les requêtes qui ont au moins un document pertinent dans le calcul du Rappel/F1
        if total_relevant > 0:
            all_precision.append(p)
            all_recall.append(r)
            all_f1.append(f1)
            
            # 2. Calcul de l'AUC
            auc_score = calculate_auc(q_id, ranked_results, qrels_valid)
            if not np.isnan(auc_score):
                 all_auc.append(auc_score)
                 
            valid_query_count += 1
            
    except Exception as e:
        # Gérer les exceptions potentielles (comme un KeyError si un doc_id est manquant dans l'embedding)
        continue

# Calcul de la moyenne sur toutes les requêtes (Mean Average)
print(f"Nombre de requêtes valides (avec au moins 1 pertinent) : {valid_query_count}")
print(f"K={K}")
print(f"Mean Precision : {np.mean(all_precision):.4f}")
print(f"Mean Recall : {np.mean(all_recall):.4f}")
print(f"Mean F1-Score : {np.mean(all_f1):.4f}")
print(f"Mean AUC: {np.mean(all_auc):.4f}")
# Out:
# Démarrage de l'évaluation sur 700 requêtes.
# Nombre de requêtes valides (avec au moins 1 pertinent) : 700
# K=10
# Mean Precision : 0.4647
# Mean Recall :    0.9427
# Mean F1-Score : 0.6315
# Mean AUC: 0.9556
